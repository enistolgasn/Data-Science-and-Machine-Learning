# %%
x = 5
y = 2

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
y = 5

# %%
x >= y
# Out:
# True

# %%
x <= 5
# Out:
# True

# %%
x >= 5.0
# Out:
# True

# %%
x >= 5.001
# Out:
# False

# %%
x = 10

# %%
y = 9

# %%
x
# Out:
# 10

# %%
y
# Out:
# 9

# %%
x = y

# %%
x
# Out:
# 9

# %%
y
# Out:
# 9

# %%
x = 10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 9

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
2 > 1 and 3 > 2
# Out:
# True

# %%
2 > 1 and 3 < 2
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
2 > 1 or 3 < 2
# Out:
# True

# %%
1 > 2 or 3 < 2
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %%
10 in [10, 20, 30]
# Out:
# True

# %%
5 not in [10, 20, 30]
# Out:
# True

# %%
5 in [10, 20, 30]
# Out:
# False

# %%
10 in {10, 20, 30}
# Out:
# True

# %%
my_dict = {"a": 10, "b": 20, "c": 30}

# %%
10 in my_dict
# Out:
# False

# %%
10 in my_dict.values()
# Out:
# True

# %%
"b" in my_dict.keys()
# Out:
# True

# %%
10 in (10, 20, 30)
# Out:
# True

# %%
my_superhero = "Batman"

# %%
my_superhero == "Batman"
# Out:
# True

# %%
my_superhero == "Superman"
# Out:
# False

# %%
if my_superhero == "Batman":
    print("Yes! My superhero is Batman.")
# Out:
# Yes! My superhero is Batman.

# %%
if my_superhero == "Superman":
    print("Yes! My superhero is Superman.")

print("Hello Python")
# Out:
# Hello Python

# %%
my_superhero = input("Enter superhero")

# %%
my_superhero
# Out:
# 'Superman'

# %%
if my_superhero == "Superman":
    print("Yes! My superhero is Superman.")
elif my_superhero == "Batman":
    print("Yes! My superhero is Batman.")
elif my_superhero == "Aquaman":
    print("Yes! My superhero is Aquaman.")
else:
    print("Not found.")
# Out:
# Yes! My superhero is Superman.
