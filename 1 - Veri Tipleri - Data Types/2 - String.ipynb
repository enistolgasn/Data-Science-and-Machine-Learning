# %% [markdown]
# STRINGS

# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello python")
# Out:
# hello python

# %%
name = "Ali"

# %%
print(name)
# Out:
# Ali

# %%
name = "veli"

# %%
print(name)
# Out:
# veli

# %%
name.capitalize()
# Out:
# 'Veli'
