# %%
import numpy as np
import pandas as pd

# %%
grades = {"Alice": 50, "James": 60, "Lars": 30}

# %%
pd.Series(grades)
# Out:
# Alice    50
# James    60
# Lars     30
# dtype: int64

# %% [markdown]
# Data Frame

# %%
data = np.random.rand(4, 3)

# %%
data
# Out:
# array([[0.46358011, 0.78320586, 0.79173693],
#        [0.85648084, 0.21762793, 0.51192629],
#        [0.27645005, 0.16024356, 0.27571359],
#        [0.7562294 , 0.68553431, 0.17376014]])

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0  0.463580  0.783206  0.791737
# 1  0.856481  0.217628  0.511926
# 2  0.276450  0.160244  0.275714
# 3  0.756229  0.685534  0.173760
