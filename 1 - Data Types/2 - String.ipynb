# %% [markdown]
# STRINGS

# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello python")
# Out:
# hello python

# %%
name = "Ali"

# %%
print(name)
# Out:
# Ali

# %%
name = "veli"

# %%
print(name)
# Out:
# veli

# %% [markdown]
# STRING METHODLARI - STRING METHODS

# %%
name.capitalize()
# Out:
# 'Veli'

# %%
# The help section will explain how to use the provided method.
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
name = "ali kara"

# %%
# The following code will print the number of ‘a’ letters in the variable name. The count method performs this operation.
name.count("a")
# Out:
# 3

# %%
# upper converts all the letters in a string to uppercase.
name.upper()
# Out:
# 'ALI KARA'

# %%
# The len method returns the length of the value inside it.
len(name)
# Out:
# 8

# %%
# \n --> New line
print("new\nline")
# Out:
# new
# line

# %%
# \t --> Tab
print("tab\ttab")
# Out:
# tab	tab
