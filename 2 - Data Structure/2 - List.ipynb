# %% [markdown]
# LİSTE - LIST

# %%
my_list = [10, 20, 30]

# %%
type(my_list)
# Out:
# list

# %%
my_list
# Out:
# [10, 20, 30]

# %%
type(my_list[0])
# Out:
# int

# %%
my_list[0]
# Out:
# 10

# %%
my_list[0] = 100

# %%
my_list
# Out:
# [100, 20, 30]

# %%
my_list[-1]
# Out:
# 30

# %%
my_list[-2]
# Out:
# 20

# %%
# The append method adds a new value to the list.
my_list.append(80)

# %%
my_list
# Out:
# [100, 20, 30, 80]

# %%
my_list.count(20)
# Out:
# 1

# %%
my_list.index(100)
# Out:
# 0

# %%
# With the insert method, we can specify where the value will be added. The code below will add the value 90 at index 2.
my_list.insert(2, 90)

my_list
# Out:
# [100, 20, 90, 30, 80]

# %%
# The pop method removes the last value from the list.
my_list.pop()

my_list
# Out:
# [100, 20, 90, 30]

# %%
# The remove method removes the specified value from the list.
my_list.remove(90)

my_list
# Out:
# [100, 20, 30]

# %%
# The reverse method reverses the list.
my_list.reverse()

# %%
my_list
# Out:
# [30, 20, 100]

# %%
x = input("enter x")

# %%
x
# Out:
# '10'

# %%
type(x)
# Out:
# str

# %%
y = input("enter y")

# %%
y
# Out:
# '20'

# %%
z = input("enter z")

# %%
z
# Out:
# '30'

# %%
input_list = []

# %%
input_list
# Out:
# []

# %%
input_list.append(x)
input_list.append(y)
input_list.append(z)

# %%
input_list
# Out:
# ['10', '20', '30']

# %%
input_list[1]
# Out:
# '20'

# %%
input_list[1] * 2
# Out:
# '2020'

# %%
type(input_list[1])
# Out:
# str

# %%
my_integer = 50

# %%
str(my_integer)
# Out:
# '50'

# %%
my_string = "40"

# %%
int(my_string)
# Out:
# 40

# %%
float(my_string)
# Out:
# 40.0

# %%
int(input_list[1]) * 2
# Out:
# 40

# %%
list_1 = [10, 20, 30]
list_2 = [40, 50, 60]

# %%
list_1 + list_2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list_1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
mixed_list = ["test", 100, 3.14]

# %%
type(mixed_list[0])
# Out:
# str

# %%
type(mixed_list[1])
# Out:
# int

# %%
type(mixed_list[2])
# Out:
# float

# %%
nested_list = [10, 20, 3.14, "test", [1, 2, 3]]

# %%
nested_list[0]
# Out:
# 10

# %%
nested_list[1]
# Out:
# 20

# %%
nested_list[2]
# Out:
# 3.14

# %%
nested_list[3]
# Out:
# 'test'

# %%
nested_list[4]
# Out:
# [1, 2, 3]

# %%
nested_list[4][1]
# Out:
# 2
