# %%
import numpy as np

# %%
my_list = [10, 20, 30, 40]

# %%
type(my_list)
# Out:
# list

# %%
my_numpy_array = np.array(my_list)

# %%
type(my_numpy_array)
# Out:
# numpy.ndarray

# %%
my_numpy_array.max()
# Out:
# np.int64(40)

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.random.random(5)
# Out:
# array([0.0214018 , 0.74042144, 0.30821974, 0.50675531, 0.37422843])
