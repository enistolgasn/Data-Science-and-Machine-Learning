# %%
name: str = "test"

# %%
type(name)
# Out:
# str

# %%
def add_numbers(a: int, b: int) -> int:
    return a + b

# %%
add_numbers(4, 5)
# Out:
# 9

# %%
from typing import List

def sum_list(numbers: List[int]) -> int:
    return sum(numbers)

# %%
numbers = [1, 2, 3, 4]
sum_list(numbers)
# Out:
# 10
