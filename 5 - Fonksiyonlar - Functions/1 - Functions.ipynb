# %% [markdown]
# FUNCTIONS

# %%
def hello_python():
    print("hello")
    print("python")

# %%
hello_python
# Out:
# <function __main__.hello_python()>

# %%
hello_python()
# Out:
# hello
# python

# %%
def hello_name(name):
    print("hello")
    print(name)

# %%
hello_name("java")
# Out:
# hello
# java

# %%
def sum_example(num1, num2):
    print(num1 + num2)

# %%
sum_example(5, 4)
# Out:
# 9
