# %% [markdown]
# SÖZLÜK - DICTIONARY

# %%
fruit_list = ["banana", "apple"]

# %%
calorie_list = [100, 150]

# %%
fruit_list[0]
# Out:
# 'banana'

# %%
calorie_list[0]
# Out:
# 100

# %%
fitness_dictionary = {"banana": 100, "apple": 150}

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
fitness_dictionary["banana"]
# Out:
# 100

# %%
fitness_dictionary["apple"]
# Out:
# 150

# %%
fitness_dictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values()
# Out:
# dict_values([100, 150])

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
list(fitness_dictionary.values())
# Out:
# [100, 150]

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 150}

# %%
fitness_dictionary["banana"] = 200

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150}

# %%
fitness_dictionary["melon"] = 300

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
fitness_dictionary.get("apple", 0)
# Out:
# 150

# %%
fitness_dictionary.get("appl", 0)
# Out:
# 0

# %%
my_mixed_dict = {"key1": 100, "key2": 3.14, "key3": [10, 20, 30]}

# %%
my_mixed_dict
# Out:
# {'key1': 100, 'key2': 3.14, 'key3': [10, 20, 30]}

# %%
my_mixed_dict["key1"]
# Out:
# 100

# %%
my_mixed_dict["key2"]
# Out:
# 3.14

# %%
my_mixed_dict["key3"]
# Out:
# [10, 20, 30]

# %%
my_mixed_dict["key3"][1]
# Out:
# 20

# %%
my_dict = {"k1": 10, "k2": [10, 20, 30, 40, 50], "k3": "string", "k4": {"a": 100, "b": 200}}

# %%
my_dict["k4"]["b"]
# Out:
# 200

# %%
my_dict["k2"][3]
# Out:
# 40
