# %% [markdown]
# TUPLE

# %%
my_tuple = (10, "a", "b", 3.14)

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tuple[0]
# Out:
# 10

# %%
# my_tuple[0] = 100 → This cannot be done, because tuples are immutable. (Immutability)

# Once a tuple is created, no new elements can be added, and the data inside it cannot be changed.

# %%
my_tuple.index("a")
# Out:
# 1

# %%
my_tuple.count("a")
# Out:
# 1
