# %% [markdown]
# SET

# %%
# There can only be one of each element, and they cannot be ordered.

# %%
my_list = [10, 20, 30, 10, 20, 40, 10, 20, 40]

# %%
len(my_list)
# Out:
# 9

# %%
my_list
# Out:
# [10, 20, 30, 10, 20, 40, 10, 20, 40]

# %%
my_set = set(my_list)

# %%
my_set
# Out:
# {10, 20, 30, 40}

# %%
second_set = {10, 20, 30, 10, 20, 40, 10, 20, 40}

# %%
second_set
# Out:
# {10, 20, 30, 40}

# %%
second_set.add(10)

# %%
second_set
# Out:
# {10, 20, 30, 40}

# %%
second_set.add(50)

# %%
second_set
# Out:
# {10, 20, 30, 40, 50}

# %%
third_set = {30, 40, 50, 60, 70}

# %%
second_set
# Out:
# {10, 20, 30, 40, 50}

# %%
third_set
# Out:
# {30, 40, 50, 60, 70}

# %%
# The following command will combine the second_set and third_set values. It reduces duplicate values ​​to a single value.
second_set.union(third_set)
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
# Intersection finds the intersections of two sets.
second_set.intersection(third_set)
# Out:
# {30, 40, 50}

# %%
country_list = ["DE", "FR", "TR", "FR", "TR", "TR", "DE", "NL", "DE", "TR"]

# %%
len(country_list)
# Out:
# 10

# %%
set(country_list)
# Out:
# {'DE', 'FR', 'NL', 'TR'}

# %%
len(set(country_list))
# Out:
# 4

# %%
empty_list = []

# %%
empty_list.append(10)
empty_list.append(20)
empty_list.append(30)

# %%
empty_list
# Out:
# [10, 20, 30]

# %%
empty_set = {}

# %%
type(empty_set)
# Out:
# dict

# %%
# To create an empty set, we use set() directly, because Python interprets {} as a dictionary.
empty_set = set()

# %%
type(empty_set)
# Out:
# set

# %%
len(empty_set)
# Out:
# 0

# %%
empty_set.add(10)
empty_set.add(10)
empty_set.add(10)
empty_set.add(20)
empty_set.add(30)

# %%
empty_set
# Out:
# {10, 20, 30}

# %%
empty_list = list()

# %%
empty_list.append(10)
empty_list.append(20)
empty_list.append(30)

# %%
empty_list
# Out:
# [10, 20, 30]

# %%
empty_dict = dict()

# %%
empty_dict["a"] = 10
empty_dict["b"] = 20

# %%
empty_dict
# Out:
# {'a': 10, 'b': 20}
